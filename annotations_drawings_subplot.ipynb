# %%
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure()
ax = fig.add_subplot(1,1,1)

data = pd.read_csv("pydata-book-master_ch09_stock_px.txt", index_col=0, parse_dates = True)
spx = data["SPX"]

spx.plot(ax=ax, style='k-')

crisis_data =[(datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearnd Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankrupcy')]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) +80),
               xytext= (date, spx.asof(date) +200),
               arrowprops= dict(facecolor = "black", headwidth=4, width=2, headlength=4),
               horizontalalignment= "left",
               verticalalignment= "top")
    
ax.set_xlim(["1/1/2007", "1/1/2011"])
ax.set_ylim([600,1800])

ax.set_title("Important dates in the 2008-2009 financial crisis")

plt.plot(data)
# Out:
# [<matplotlib.lines.Line2D at 0x120dcce80>,
#  <matplotlib.lines.Line2D at 0x121133048>,
#  <matplotlib.lines.Line2D at 0x121147c18>,
#  <matplotlib.lines.Line2D at 0x121147898>]
